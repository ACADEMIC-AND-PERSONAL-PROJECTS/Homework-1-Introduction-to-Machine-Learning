# %% [markdown]
# # Homework 1: Introduction to Machine Learning

# %% [markdown]
# ### Q1. Pandas version

# %%
import pandas as pd

pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# The version of pandas installed in this notebook is: `3.0.5`

# %% [markdown]
# ### Getting the data

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Out:
# 7[Files: 0  Bytes: 0  [0 B/s] Re]87[https://raw.githubusercontent.]87Saving 'car_fuel_efficiency_2026.csv'
# 87car_fuel_efficiency_  28% [=======>                      ]   33.30K    --.-KB/s87[Files: 0  Bytes: 0  [0 B/s] Re]87car_fuel_efficiency_ 100% [=============================>]  116.79K  684.33KB/s87HTTP response 200  [https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv]
# 87car_fuel_efficiency_ 100% [=============================>]  116.79K  684.33KB/s87[Files: 1  Bytes: 116.79K [104.]8

# %%
df = pd.read_csv('car_fuel_efficiency_2026.csv')

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %% [markdown]
# ### Q2. Records count

# %%
df.shape
# Out:
# (10000, 11)

# %% [markdown]
# There are 10000 records in this dataset.

# %% [markdown]
# ### Q3. Fuel types

# %%
df['fuel_type'].unique()
# Out:
# <StringArray>
# ['Gasoline', 'Diesel', 'Hybrid']
# Length: 3, dtype: str

# %% [markdown]
# 3 fuel type are presented in this dataset.

# %% [markdown]
# ### Q4. Missing values

# %%
df.isna().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# 2 columns have missing values

# %% [markdown]
# ### Q5. Max fuel efficiency

# %%
df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %% [markdown]
# The maximum fuel efficiency of cars from Asia is 41.2

# %% [markdown]
# ### Q6. Median value of horsepower

# %% [markdown]
# 1. Find the median value of the `horsepower` column in the dataset.

# %%
pd.DataFrame(df['horsepower'].describe()).T
# Out:
#              count        mean        std    min    25%    50%    75%    max
# horsepower  9123.0  254.446016  22.844613  171.0  239.0  254.0  270.0  334.0

# %% [markdown]
# 2. Next, calculate the most frequent value of the same `horsepower` column.

# %%
df['horsepower'].value_counts()
# Out:
# horsepower
# 252.0    174
# 246.0    168
# 256.0    168
# 259.0    165
# 253.0    165
#         ...
# 322.0      1
# 330.0      1
# 175.0      1
# 178.0      1
# 320.0      1
# Name: count, Length: 153, dtype: int64

# %% [markdown]
# 3. Use the fillna method to fill the missing values in the `horsepower` column with the most frequent value from the previous step.

# %%
df['horsepower'] = df['horsepower'].fillna(252.0)

# %%
df['horsepower'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 4. Now, calculate the median value of `horsepower` once again.

# %%
pd.DataFrame(df['horsepower'].describe()).T
# Out:
#               count      mean        std    min    25%    50%    75%    max
# horsepower  10000.0  254.2315  21.830757  171.0  241.0  252.0  268.0  334.0

# %% [markdown]
# Yes, it decreased

# %% [markdown]
# ### Q7. Sum of weights

# %% [markdown]
# 1. Select all the cars from Asia

# %%
df_asia = df[df['origin'] == 'Asia']

# %%
df_asia.head()
# Out:
#     model_year origin fuel_type         drivetrain  num_doors  \
# 2         1996   Asia  Gasoline  Front-wheel drive          5
# 6         1992   Asia  Gasoline  Front-wheel drive          2
# 8         1997   Asia  Gasoline   Rear-wheel drive          3
# 10        1978   Asia  Gasoline    All-wheel drive          3
# 15        2007   Asia    Diesel  Front-wheel drive          4
#
#     engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                  2320              6       267.0            4240
# 6                  2270              6       250.0            4310
# 8                  2330              6       251.0            4230
# 10                 2410              6       252.0            4420
# 15                 2170              5       226.0            3950
#
#     acceleration  fuel_efficiency_mpg
# 2           17.3                 27.5
# 6           21.7                 26.8
# 8           19.5                 30.9
# ...

# %% [markdown]
# 2. Select only columns `vehicle_weight` and `model_year`

# %%
df_filtered_columns = df_asia[['vehicle_weight', 'model_year']]

# %%
df_filtered_columns.head()
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007

# %% [markdown]
# 3. Select the first 7 values

# %%
df_seven = df_filtered_columns.head(7)

# %% [markdown]
# 4. Get the underlying NumPy array. Let's call it `X`.

# %%
X = df_seven.to_numpy()
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %% [markdown]
# 5. Compute matrix-matrix multiplication between the transpose of `X` and X. To get the transpose, use `X.T`. Let's call the result `XTX`

# %%
XTX = X.T @ X

# %%
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %% [markdown]
# 5. Invert `XTX`

# %%
import numpy as np

# %%
XTX_inverted = np.linalg.inv(XTX)

# %% [markdown]
# 6. Create an array `y` with values `[1100, 1300, 800, 900, 1000, 1100, 1200]`.

# %%
y = np.array([[1100, 1300, 800, 900, 1000, 1100, 1200]])

# %% [markdown]
# 8. Multiply the inverse of `XTX` with the transpose of `X`, and then multiply the result by `y`. Call the result `w`.

# %%
w = (XTX_inverted @ X.T) @ y.T
w
# Out:
# array([[0.13644777],
#        [0.2327492 ]])

# %% [markdown]
# 9. What's the sum of all the elements of the result?

# %%
w.sum()
# Out:
# np.float64(0.36919696904925486)

# %% [markdown]
# The sum of all elements of the result is: `0.369`

# %% [markdown]
# ---
